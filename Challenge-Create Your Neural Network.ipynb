# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import cross_val_score
from sklearn import ensemble
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn import datasets
from sklearn.utils import shuffle
# Out:
# /Users/samuelkim/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %% [markdown]
# We will use the 2014 NYC Crime dataset we have used in previous exercises.

# %%
excel_file='Table_8_Offenses_Known_to_Law_Enforcement_by_New_York_by_City_2014.xls'
df=pd.read_excel(excel_file)
df.head()
# Out:
#                              Table 8  Unnamed: 1      Unnamed: 2  \
# 0                           NEW YORK         NaN             NaN
# 1  Offenses Known to Law Enforcement         NaN             NaN
# 2                      by City, 2014         NaN             NaN
# 3                               City  Population  Violent\ncrime
# 4                      Adams Village        1851               0
#
#                                Unnamed: 3                    Unnamed: 4  \
# 0                                     NaN                           NaN
# 1                                     NaN                           NaN
# 2                                     NaN                           NaN
# 3  Murder and\nnonnegligent\nmanslaughter  Rape\n(revised\ndefinition)1
# 4                                       0                           NaN
#
#                     Unnamed: 5 Unnamed: 6           Unnamed: 7  \
# 0                          NaN        NaN                  NaN
# 1                                     NaN                  NaN
# 2                          NaN        NaN                  NaN
# 3  Rape\n(legacy\ndefinition)2    Robbery  Aggravated\nassault
# 4                            0          0                    0
#
#         Unnamed: 8 Unnamed: 9      Unnamed: 10            Unnamed: 11  \
# 0              NaN        NaN              NaN                    NaN
# 1              NaN        NaN              NaN                    NaN
# 2              NaN        NaN              NaN                    NaN
# 3  Property\ncrime   Burglary  Larceny-\ntheft  Motor\nvehicle\ntheft
# 4               11          1               10                      0
#
#   Unnamed: 12
# 0         NaN
# 1         NaN
# 2         NaN
# 3      Arson3
# 4           0

# %%
columns=['City','Population','Violent Crime','Murder/Manslaughter','Rape','Rape Legacy','Robbery','Agg Assault',
           'Property Crime','Burgulary','Larceny','Motor_Vehicle Theft','Arson']

df.columns=columns
df[columns]=df[columns].replace(',', '', regex=True)
df.drop(df.head(4).index, inplace=True)
df_new=df.drop(['Rape', 'Arson'], axis=1)
df_new.head()
# Out:
#                        City Population Violent Crime Murder/Manslaughter  \
# 4             Adams Village       1851             0                   0
# 5  Addison Town and Village       2568             2                   0
# 6            Afton Village4        820             0                   0
# 7             Akron Village       2842             1                   0
# 8                   Albany4      98595           802                   8
#
#   Rape Legacy Robbery Agg Assault Property Crime Burgulary Larceny  \
# 4           0       0           0             11         1      10
# 5           0       1           1             49         1      47
# 6         NaN       0           0              1         0       1
# 7           0       0           1             17         0      17
# 8         NaN     237         503           3888       683    3083
#
#   Motor_Vehicle Theft
# 4                   0
# 5                   1
# 6                   0
# 7                   0
# 8                 122

# %%
df_new['Population^2']=df_new['Population'].apply(float)**2
df_new['Murder_new']=np.where(df_new['Murder/Manslaughter'] > 0, 1, 0)
df_new['Robbery_new']=np.where(df_new['Robbery'].apply(float) > 0, 1, 0)
df_new.head()
# Out:
#                        City Population Violent Crime Murder/Manslaughter  \
# 4             Adams Village       1851             0                   0
# 5  Addison Town and Village       2568             2                   0
# 6            Afton Village4        820             0                   0
# 7             Akron Village       2842             1                   0
# 8                   Albany4      98595           802                   8
#
#   Rape Legacy Robbery Agg Assault Property Crime Burgulary Larceny  \
# 4           0       0           0             11         1      10
# 5           0       1           1             49         1      47
# 6         NaN       0           0              1         0       1
# 7           0       0           1             17         0      17
# 8         NaN     237         503           3888       683    3083
#
#   Motor_Vehicle Theft  Population^2  Murder_new  Robbery_new
# 4                   0  3.426201e+06           0            0
# 5                   1  6.594624e+06           0            1
# 6                   0  6.724000e+05           0            0
# 7                   0  8.076964e+06           0            0
# 8                 122  9.720974e+09           1            1

# %%
#If a neighborhood has had a Murder and/or Robbery in 2014, we created a new column "Attn" to point this out. 
#53.2% of neighborhoods have had a murder and/or robbery taking place in the past year.
df_new['Attention'] = np.where(df_new['Murder_new']+df_new['Robbery_new'] >=1, 1, 0)
print('Trouble Neighborhoods:', df_new['Attention'].mean())
df_new.tail()
# Out:
# Trouble Neighborhoods: 0.5319148936170213
#                                                   City Population  \
# 375  3 The FBI does not publish arson data unless i...        NaN
# 376  4 This agency began the year submitting rape d...        NaN
# 377  5 The FBI determined that the agency's data we...        NaN
# 378                                                NaN        NaN
# 379                                                           NaN
#
#     Violent Crime Murder/Manslaughter Rape Legacy Robbery Agg Assault  \
# 375           NaN                 NaN         NaN     NaN         NaN
# 376           NaN                 NaN         NaN     NaN         NaN
# 377           NaN                 NaN         NaN     NaN         NaN
# 378           NaN                 NaN         NaN     NaN         NaN
# 379           NaN                 NaN         NaN     NaN         NaN
#
#     Property Crime Burgulary Larceny Motor_Vehicle Theft  Population^2  \
# 375            NaN       NaN     NaN                 NaN           NaN
# 376            NaN       NaN     NaN                 NaN           NaN
# 377            NaN       NaN     NaN                 NaN           NaN
# 378            NaN       NaN     NaN                 NaN           NaN
# 379            NaN       NaN     NaN                 NaN           NaN
#
#      Murder_new  Robbery_new  Attention
# 375           0            0          0
# 376           0            0          0
# 377           0            0          0
# 378           0            0          0
# 379           0            0          0

# %%
df_new.replace([np.inf,-np.inf],np.nan)
df_new.dropna(how='any')
# Out:
#                            City Population Violent Crime Murder/Manslaughter  \
# 4                 Adams Village       1851             0                   0
# 5      Addison Town and Village       2568             2                   0
# 7                 Akron Village       2842             1                   0
# 15           Amityville Village       9509            12                   0
# 16                    Amsterdam      18099            27                   0
# 18               Arcade Village       2030             0                   0
# 19              Ardsley Village       4561             1                   0
# 20            Asharoken Village        656             0                   0
# 21               Attica Village       2502             0                   0
# 31                  Black River       1392             0                   0
# 33                  Bolton Town       2321             0                   0
# 34            Boonville Village       2053             1                   0
# 35                   Brant Town       2063             1                   0
# 36                     Brewster       2349             0                   0
# 37     Briarcliff Manor Village       8060             2                   0
# 40           Bronxville Village       6421             2                   0
# 41           Brownville Village       1162             0                   0
# 45               Camden Village       2214             2                   0
# 46    Camillus Town and Village      24307            13                   0
# 47          Canajoharie Village       2168             1                   0
# 50             Canisteo Village       2236             1                   0
# 53                 Carroll Town       3461             4                   0
# 55          Cattaraugus Village        975             1                   0
# 58       Central Square Village       1839             4                   0
# 60              Chatham Village       1721             0                   0
# 69           Cobleskill Village       4488             0                   0
# 70                Coeymans Town       7441            20                   1
# 75   Cornwall-on-Hudson Village       2964             2                   0
# 83                  Dewitt Town      22682            20                   0
# 84               Dexter Village       1114             0                   0
# ..                          ...        ...           ...                 ...
# 288    Rockville Centre Village      24127            17                   0
# 291              Rotterdam Town      29340            13                   1
# 292        Rouses Point Village       2186             0                   0
# 294           Rye Brook Village       9544             2                   0
# 296          Sag Harbor Village       2275             0                   0
# 298         Sands Point Village       2727             0                   0
# 301             Saugerties Town      19227            11                   0
# 302           Scarsdale Village      17710             1                   0
# 305           Schoharie Village        857             0                   0
# 312         Shortsville Village       1429             0                   0
# 314         Skaneateles Village       2453             1                   0
# 315       Sleepy Hollow Village      10051             8                   0
# 318              Solvay Village       6467            19                   0
# 320         Southampton Village       3158             2                   0
# 325             Stillwater Town       6604             0                   0
# 327              Stockport Town       2744             0                   0
# 329             Suffern Village      10975             5                   1
# 331           Tarrytown Village      11531             6                   0
# 335                        Troy      49950           350                   7
# 337            Tuckahoe Village       6620             2                   0
# 339         Tuxedo Park Village        612             0                   0
# 343              Vernon Village       1166             1                   0
# 349     Washingtonville Village       5788             2                   0
# 350  Waterford Town and Village       8398             1                   0
# 357           Weedsport Village       1796             2                   0
# 358          Wellsville Village       4576            18                   0
# 360   Westhampton Beach Village       1753             2                   0
# 364          Whitesboro Village       3727             5                   0
# 365             Whitestown Town       9307             0                   0
# 367             Wolcott Village       1646             0                   0
#
#     Rape Legacy Robbery Agg Assault Property Crime Burgulary Larceny  \
# 4             0       0           0             11         1      10
# 5             0       1           1             49         1      47
# 7             0       0           1             17         0      17
# 15            0      11           1            198        10     175
# 16            0      15          12            490       107     370
# 18            0       0           0             25         7      18
# 19            0       0           1             25         6      19
# 20            0       0           0              6         0       4
# 21            0       0           0             12         0      12
# 31            0       0           0              3         1       2
# 33            0       0           0              9         3       6
# 34            0       0           1             10         0      10
# 35            0       0           1             21         9      12
# 36            0       0           0              9         2       6
# 37            0       0           2             17         4      13
# 40            0       2           0             25         5      20
# 41            0       0           0              5         1       4
# 45            0       0           2             35         4      31
# 46            0       3          10            470        35     429
# 47            0       0           1             12         2      10
# 50            0       0           1              9         2       7
# 53            0       0           4              4         0       4
# 55            0       0           1              2         1       1
# 58            0       1           3             40         5      34
# 60            0       0           0              9         0       9
# 69            0       0           0            151        13     137
# 70            0       3          16             63        14      44
# 75            0       0           2             23         3      20
# 83            0       7          13            685        97     577
# 84            0       0           0              9         1       8
# ..          ...     ...         ...            ...       ...     ...
# 288           0      10           7            194         8     174
# 291           0       4           8            901       110     769
# 292           0       0           0             21         9      12
# 294           0       2           0             92        12      78
# 296           0       0           0             57         5      51
# 298           0       0           0              9         0       6
# 301           0       3           8            217        43     168
# 302           0       1           0            129        24     102
# 305           0       0           0              0         0       0
# 312           0       0           0              0         0       0
# 314           0       0           1              6         0       6
# 315           0       4           4             53        10      41
# 318           0       6          13            143        26     109
# 320           0       0           2             84         6      77
# 325           0       0           0             29         5      23
# 327           0       0           0              1         1       0
# 329           0       0           4             61        10      50
# 331           0       3           3             86        20      63
# 335           0     110         233           2182       540    1512
# 337           0       0           2             45         3      38
# 339           0       0           0              0         0       0
# 343           0       0           1             15         2      13
# 349           0       0           2             59         5      53
# 350           0       1           0             58        14      44
# 357           0       0           2             21         7      14
# 358           0       0          18            156        40     114
# 360           0       0           2             33         8      23
# 364           0       1           4             41        10      29
# 365           0       0           0             71        16      55
# 367           0       0           0              4         0       4
#
#     Motor_Vehicle Theft  Population^2  Murder_new  Robbery_new  Attention
# 4                     0  3.426201e+06           0            0          0
# 5                     1  6.594624e+06           0            1          1
# 7                     0  8.076964e+06           0            0          0
# 15                   13  9.042108e+07           0            1          1
# 16                   13  3.275738e+08           0            1          1
# 18                    0  4.120900e+06           0            0          0
# 19                    0  2.080272e+07           0            0          0
# 20                    2  4.303360e+05           0            0          0
# 21                    0  6.260004e+06           0            0          0
# 31                    0  1.937664e+06           0            0          0
# 33                    0  5.387041e+06           0            0          0
# 34                    0  4.214809e+06           0            0          0
# 35                    0  4.255969e+06           0            0          0
# 36                    1  5.517801e+06           0            0          0
# 37                    0  6.496360e+07           0            0          0
# 40                    0  4.122924e+07           0            1          1
# 41                    0  1.350244e+06           0            0          0
# 45                    0  4.901796e+06           0            0          0
# 46                    6  5.908302e+08           0            1          1
# 47                    0  4.700224e+06           0            0          0
# 50                    0  4.999696e+06           0            0          0
# 53                    0  1.197852e+07           0            0          0
# 55                    0  9.506250e+05           0            0          0
# 58                    1  3.381921e+06           0            1          1
# 60                    0  2.961841e+06           0            0          0
# 69                    1  2.014214e+07           0            0          0
# 70                    5  5.536848e+07           1            1          1
# 75                    0  8.785296e+06           0            0          0
# 83                   11  5.144731e+08           0            1          1
# 84                    0  1.240996e+06           0            0          0
# ..                  ...           ...         ...          ...        ...
# 288                  12  5.821121e+08           0            1          1
# 291                  22  8.608356e+08           1            1          1
# 292                   0  4.778596e+06           0            0          0
# 294                   2  9.108794e+07           0            1          1
# 296                   1  5.175625e+06           0            0          0
# 298                   3  7.436529e+06           0            0          0
# 301                   6  3.696775e+08           0            1          1
# 302                   3  3.136441e+08           0            1          1
# 305                   0  7.344490e+05           0            0          0
# 312                   0  2.042041e+06           0            0          0
# 314                   0  6.017209e+06           0            0          0
# 315                   2  1.010226e+08           0            1          1
# 318                   8  4.182209e+07           0            1          1
# 320                   1  9.972964e+06           0            0          0
# 325                   1  4.361282e+07           0            0          0
# 327                   0  7.529536e+06           0            0          0
# 329                   1  1.204506e+08           1            0          1
# 331                   3  1.329640e+08           0            1          1
# 335                 130  2.495002e+09           1            1          1
# 337                   4  4.382440e+07           0            0          0
# 339                   0  3.745440e+05           0            0          0
# 343                   0  1.359556e+06           0            0          0
# 349                   1  3.350094e+07           0            0          0
# 350                   0  7.052640e+07           0            1          1
# 357                   0  3.225616e+06           0            0          0
# 358                   2  2.093978e+07           0            0          0
# 360                   2  3.073009e+06           0            0          0
# 364                   2  1.389053e+07           0            1          1
# 365                   0  8.662025e+07           0            0          0
# 367                   0  2.709316e+06           0            0          0
#
# [142 rows x 15 columns]

# %%
X = df_new[['Population', 'Agg Assault', 'Rape Legacy', 'Property Crime', 'Murder_new', 'Robbery_new', 'Attention']].copy().dropna()
data = X.Attention
Y = data

# %%
Y.shape
# Out:
# (142,)

# %%
X.shape
# Out:
# (142, 7)

# %% [markdown]
# # Our Neural Network

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
# Establish and fit with single, 100 perceptron layer 
mlp = MLPClassifier(hidden_layer_sizes=(100,))
mlp.fit(X,Y)
# Cross validate and get scores
cross_val_score(mlp, X, Y, cv=5)
# Out:
# array([0.55172414, 0.44827586, 0.42857143, 0.42857143, 0.57142857])

# %%
mlp = MLPClassifier(hidden_layer_sizes=(1000,))
mlp.fit(X,Y)
# Cross validate and get scores
cross_val_score(mlp, X, Y, cv=5)
# Out:
# array([0.44827586, 0.44827586, 0.42857143, 0.42857143, 0.42857143])

# %%
mlp = MLPClassifier(hidden_layer_sizes=(100, 100))
mlp.fit(X,Y)
# Cross validate and get scores
cross_val_score(mlp, X, Y, cv=5)
# Out:
# array([0.44827586, 0.44827586, 0.42857143, 0.42857143, 0.42857143])

# %%
mlp = MLPClassifier(
    hidden_layer_sizes=(100,),
    activation='tanh',
    alpha=10, 
    learning_rate='adaptive'
)
mlp.fit(X,Y)

# Cross validate and get scores
cross_val_score(mlp, X, Y, cv=5)
# Out:
# array([0.55172414, 0.5862069 , 0.57142857, 0.57142857, 0.57142857])

# %%
mlp = MLPClassifier(
    hidden_layer_sizes=(1000,),
    activation='tanh',
    alpha=10, 
    learning_rate='adaptive'
)
mlp.fit(X,Y)

# Cross validate and get scores
cross_val_score(mlp, X, Y, cv=5)
# Out:
# array([0.5862069 , 0.72413793, 0.57142857, 0.57142857, 0.60714286])

# %%
mlp = MLPClassifier(
    hidden_layer_sizes=(100,100),
    activation='tanh',
    alpha=10, 
    learning_rate='adaptive'
)
mlp.fit(X,Y)

# Cross validate and get scores
cross_val_score(mlp, X, Y, cv=5)
# Out:
# /Users/samuelkim/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/samuelkim/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/samuelkim/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# array([0.79310345, 0.72413793, 0.71428571, 0.64285714, 0.78571429])

# %% [markdown]
# After working with MLP parameters, the double 100 perceptron layers performed the best with an average score of 0.711  although consistency could be improved. We will now compare the neural network's performance with a random forest.

# %% [markdown]
# # Random Forest Comparison

# %%
forest = ensemble.RandomForestClassifier(
    max_features='sqrt',
)
max_depth = dict(max_depth = np.arange(1,10,1))
grid = GridSearchCV(forest, max_depth, cv=5)
grid.fit(X, Y).best_estimator_.get_params()['max_depth']
# Out:
# 1

# %%
forest = ensemble.RandomForestClassifier(
    max_features='sqrt',
    max_depth=1
)

cross_val_score(forest, X, Y, cv=5)
# Out:
# array([1.        , 1.        , 1.        , 1.        , 0.96428571])

# %%
forest.fit(X,Y)

forest_features = pd.DataFrame()
forest_features['Importance'] = forest.feature_importances_
forest_features['Feature'] = X.columns

forest_features.sort_values('Importance', ascending=False).head(3)
#Two of three most important features in the forest are Attention and Murder_new, newly created features for the challenge
# Out:
#    Importance      Feature
# 6         0.3    Attention
# 0         0.2   Population
# 5         0.2  Robbery_new

# %% [markdown]
# # Observations

# %% [markdown]
# Juxtaposing neural network and random forest, we notice that with the right parameters, they both showed consistency across five folds. However, our RF was clearly overfitting, whereas our neural network was not. We were able to ascertain important features that were considered for RF, but not for NN. The two models varied in speed but that was negligible in this case.
